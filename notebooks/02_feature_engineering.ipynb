# %% [markdown]
# # Gestational Diabetes Meal Risk Predictor
# ## Notebook 2: Feature Engineering
#
# **Author:** Sanjay Kumar Chhetri
# **Date:** December 25, 2025
# **Project:** Springboard Capstone
#
# ---
#
# ### Objectives:
# 1. Load cleaned nutritional data from Notebook 01
# 2. Calculate glycemic load from GI and carbs
# 3. Create derived features (ratios, interactions)
# 4. Add meal context features
# 5. Generate synthetic risk labels for supervised learning
# 6. Validate feature distributions and target balance
# 7. Save feature-engineered dataset for modeling
